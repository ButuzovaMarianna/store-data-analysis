# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Привет еще раз. Спасибо, что доделала работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет! Спасибо, что прислала задание:) Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделала большую работу над проектом, однако его еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге.
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно. Рекомендации укажу таким же цветом; <font color=orange>оранжевый</font> - некритичные замечания. Если таких замечаний меньше трех - проект может быть принят без их отработки; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# </div>

# %% [markdown]
# # Сборный проект

# %% [markdown]
# 1.[Описание проекта](#Описание-проекта)
# 2.[Описание данных games.csv](#Описание-данных-games.csv)
# 3.[Открытие файла с данными и изучение общей информации](#Открытие-файла-с-данными-и-изучение-общей-информации)
# 4.[Подготовка данных](#Подготовка-данных)
# 5.[Проведение исследовательского анализа данных](#Проведем-исследовательский-анализ-данных)
# 6.[Составление портрета пользователя каждого региона](#Составим-портрет-пользователя-каждого-региона)
# 7.[Проведение исследования статистических показателей](#Проведем-исследование-статистических-показателей)
# 8.[Проверка гипотезы](#Проверка-гипотезы)
# 9.[Общий вывод](#Общий-вывод)

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.

# %% [markdown]
# ## Описание данных games.csv

# %% [markdown]
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы долларов)
# - EU_sales — продажи в Европе (миллионы долларов)
# - JP_sales — продажи в Японии (миллионы долларов)
# - Other_sales — продажи в других странах (миллионы долларов)
# - Critic_Score — оценка критиков (от 0 до 100)
# - User_Score — оценка пользователей (от 0 до 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).
# Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Правильно, что есть информация о входных данных: какие столбцы есть в таблице, их названия и какую информацию они несут. Помимо этого стоит сделать краткое введение в тему проекта. Также название работы лучше отображать в отдельной ячейке и делать крупный шрифт (заголовок). Так работа выглядит презентабельно. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Да, есть плагин ToC. Но хорошо бы уметь реализовывать интерактивный план проекта вручную. Как это реализовать - смотри по [ссылке](https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704).
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Здорово, что каждому пункту вводной информации ты уделил внимание.
#
# </div>

# %% [markdown]
# ## Открытие файла с данными и изучение общей информации

# %% [markdown]
# Подключим все необходимые библиотеки

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Я заметил, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой работы рекомендую перезапускать ноутбук, чтобы убедиться, что все ячейки выполняются корректно.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Перезапуск проекта позволяет обнаружить и исправить скрытые в коде ошибки.
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Верно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
#
# </div>

# %%
#загрузим датасет
games = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# ##  Подготовка данных

# %% [markdown]
# - Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
# - - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - - Опишите причины, которые могли привести к пропускам;
# - - Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Поясните, как обработать это значение.
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %% [markdown]
# Приведем к нижнему регистру названия столбцов

# %%
games.columns = map(str.lower, games.columns)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Данный метод позволяет нам автоматизировать процесс приведения названий столбцов к нижнему регистру. Так исключается вероятность опечаток.
#
# </div>

# %% [markdown]
# Рассмотрим информацию о данных, как можно преобразовать данные

# %%
games.head(15)
# Out:
#                            name platform  year_of_release         genre  \
# 0                    Wii Sports      Wii             2006        Sports
# 1             Super Mario Bros.      NES             1985      Platform
# 2                Mario Kart Wii      Wii             2008        Racing
# 3             Wii Sports Resort      Wii             2009        Sports
# 4      Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                        Tetris       GB             1989        Puzzle
# 6         New Super Mario Bros.       DS             2006      Platform
# 7                      Wii Play      Wii             2006          Misc
# 8     New Super Mario Bros. Wii      Wii             2009      Platform
# 9                     Duck Hunt      NES             1984       Shooter
# 10                   Nintendogs       DS             2005    Simulation
# 11                Mario Kart DS       DS             2005        Racing
# ...

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Заменим пропуски в строковых данных на  'unknown' и преобразуем в тип str

# %%
games.name = games.name.astype(str)
games.platform = games.platform.astype(str)
games.genre = games.genre.astype(str)
games.rating = games.rating.astype(str)


games.name = games.name.fillna('unknown')
games.platform = games.platform.fillna('unknown')
games.genre = games.genre.fillna('unknown')
games.rating = games.rating.fillna('unknown')

# %% [markdown]
# Заменим пропуски в данных с годами на 0 и преобразуем в тип int

# %%
games.year_of_release = games.year_of_release.fillna('0')
games.year_of_release = games.year_of_release.astype(np.int64)

# %%
games.critic_score = games.critic_score.fillna(0.0)

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Пропусков по продажам у нас нет. Зачем тогда их обрабатывать?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Заполнение такого числа пропусков в отзывах критиков и пользователей одним значением может сильно исказить структуры данных столбцов. Данных для того, чтобы восстановить эти пропуски, у нас недостаточно. Также мы видим, что пропуски в столбцах часто встречаются вместе, т.е. нет данных по одним и тем же играм. Это с большой долей вероятности связано с тем, что эти данные просто не были загружены в таблицу. Попробуй оставить пропуски и посмотреть на результаты без их заполнения.
#
# </div>

# %% [markdown]
# Посмотрим на преобразованные данные

# %%
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           0.0        NaN    nan
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           0.0        NaN    nan

# %% [markdown]
# Запишем суммарные продажи всех регионов в столбец sales

# %%
games['sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales']+games['other_sales']
print(games['sales'])
# Out:
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38
#          ...
# 16710     0.01
# 16711     0.01
# 16712     0.01
# 16713     0.01
# 16714     0.01
# Name: sales, Length: 16715, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Восстановить пропущенные значения мы не можем. Данных для этого недостаточно. Лучше работать с меньшим количеством данных хорошего качества.
#
# Ошибки в данных устранены. Данные подготовлены к дальнейшему анализу.
#
# </div>

# %% [markdown]
# ## Проведем исследовательский анализ данных

# %% [markdown]
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
count_games = games.pivot_table(values = 'name', index ='year_of_release', aggfunc='count')
print(count_games)
# Out:
#                  name
# year_of_release
# 0                 269
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               62
# 1994              121
# 1995              219
# 1996              263
# 1997              289
# 1998              379
# 1999              338
# 2000              350
# 2001              482
# 2002              829
# 2003              775
# 2004              762
# 2005              939
# 2006             1006
# 2007             1197
# 2008             1427
# 2009             1426
# 2010             1255
# 2011             1136
# 2012              653
# 2013              544
# 2014              581
# 2015              606
# 2016              502

# %% [markdown]
# Мы можем выделить 3 периода.
# Исходя из полученных данных, можно сделать вывод, что до 1990 года количество игр не растет, так как не распространнены ПК. За период с 1990 по 2008 количество компьютерных игр растет, из чего можно сделать вывод об их популярности за это время. А с 2008 года произошел спад компьютерных игр, из-за появления игр на других устройствах.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Соглашусь с причиной спада в индустрии.
# </div>

# %% [markdown]
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. Найдите популярные в прошлом платформы, у которых сейчас продажи на нуле. За какой характерный период появляются новые и исчезают старые платформы?

# %% [markdown]
# Посмотрим как менялись продажи по платформам

# %%
count_platform = games.pivot_table(values = 'sales', index ='platform',aggfunc='sum').sort_values(by='sales', ascending=False)

print(count_platform)
# Out:
#             sales
# platform
# PS2       1255.77
# X360       971.42
# PS3        939.65
# Wii        907.51
# DS         806.12
# PS         730.86
# GBA        317.85
# PS4        314.14
# PSP        294.05
# PC         259.52
# 3DS        259.00
# XB         257.74
# GB         255.46
# NES        251.05
# N64        218.68
# SNES       200.04
# GC         198.93
# XOne       159.32
# 2600        96.98
# WiiU        82.19
# PSV         54.07
# SAT         33.59
# GEN         30.77
# DC          15.95
# SCD          1.86
# NG           1.44
# WS           1.42
# TG16         0.16
# 3DO          0.10
# GG           0.04
# PCFX         0.03

# %% [markdown]
# Можно сделать вывод о том, что наиболее популярными платформами являются PS2, X360,  PS3, Wii и DS. Их распределение рассмотрим по годам.

# %%
top_platforms = games.pivot_table(index='platform', values='sales', aggfunc='sum').sort_values(by='sales', ascending=False).head(5)
top_platforms = top_platforms.reset_index().rename_axis(None, axis=1)

# %% [markdown]
# Построим график количества продаж топ - 5 игровых платформ

# %%
plt.figure(figsize=(10,10))
plt.title('Количество продаж игровых платформ')
plt.xlabel('Годы выхода компьютерных игр')
plt.ylabel('Продажи')
for i in list(top_platforms['platform']):
    total = games[(games['platform'] == i) & (games['year_of_release'] > 1980)].pivot_table(index='year_of_release', values='sales', aggfunc='sum').sort_values(by = 'year_of_release', ascending=False)
    plt.plot(total['sales'],  label=i)
    plt.legend()

# %% [markdown]
# Из данного графика можно сделать выводы:
#     1. У большинства популярных игр пик их продажи через 5 лет после выхода
#     2. Большинство самых покупаемых игры появились в начале 2000-х.
#     3. Дольше всех на рынке - DS

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Значение средней продолжительности существования платформы приведено. Однако выводы ты делаешь по графику. Стоит также привести расчет данного значения. Подумай, стоит ли включать в расчет все платформы. Будут ли выбросы по продолжительности существования платформ?
#
# </div>

# %% [markdown]
# Мы можем увидеть, что у популярных в прошлом платформ сейчас продажи на нуле.
# И за появляются новые платформы и исчезают старые

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Актуальный период не назван. Обозначь его и в дальнейшем анализе работай именно с такими данными. Учти, большей части платформ уже нет в 2016 году, в построении прогноза на 2017 год они нам не помогут. Нам важно рассматривать только конечный на данный момент интервал развития игровой индустрии.
#
# </div>

# %% [markdown]
# За актуальный период возьмем за 2016, так как в этот период развивались большинство платформ. Найдем топ 5 платформ за актуальный период

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Актуальный период не изменен. Его следует уменьшить для увеличения точности и качества прогноза на 2017 год.
#
# </div>

# %%
top_platforms_ac = games[(games['year_of_release'] > 2015)].pivot_table(index='platform', values='sales', aggfunc='sum').sort_values(by='sales', ascending=False)
top_platforms_ac = top_platforms_ac.reset_index().rename_axis(None, axis=1)
top_platforms_ac.head(5)
# Out:
#   platform  sales
# 0      PS4  69.25
# 1     XOne  26.15
# 2      3DS  15.14
# 3       PC   5.25
# 4     WiiU   4.60

# %% [markdown]
# Можно сделать вывод о перспективных платформах, что самой продаваемой платформой стала - PS4, потом XOne, 3DS, PC и WiiU.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Какие платформы мы можем назвать перспективными на 2017 год?
#
# </div>

# %% [markdown]
# Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.

# %% [markdown]
# Построим график «ящик с усами» за актуальный период каждой игры и разбивкой по платформам

# %%
list_platforms = ['PS4', 'XOne',  '3DS', 'PC', 'WiiU']
top_platforms_5 = games[games['platform'].isin(list_platforms)]
top_platforms_5 = top_platforms_5[top_platforms_5['sales']<1.4]

# %%
import seaborn as sns

plt.figure(figsize=(10,10))
sns.boxplot(data=top_platforms_5, x='platform', y='sales', palette="Set3")
plt.title('График «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам')
# Out:
# Text(0.5, 1.0, 'График «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам')

# %% [markdown]
# По графику можно сделать вывод, что медиана у всех  разная. Больше всех продаж у XOne,а меньше всех у РС. Разница между платформами может формироваться из-за новизны версии, рекламы. Медиана у WiiU и XOne находится примерно на одном уровне.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Подумай, из-за чего формируется разница между платформами. Старайся не только описывать результат, но и трактовать его.
#
# </div>

# %% [markdown]
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы и соотнесите их с продажами игр на других платформах.

# %% [markdown]
# Подсчитаем корреляцию и построим диаграмму для XOne

# %%
games.loc[games['user_score'] == 'tbd', 'user_score'] = 'NaN'
games['user_score'] = games['user_score'].astype(float)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Не следует заполнять пропуски нереальными значениями и включать их в анализ. Так ты сильно искажаешь его результаты. Посмотри на результаты анализа без обработки пропусков.
#
# </div>

# %%
xone = games[(games['platform']=='XOne')]
c = xone['user_score'].corr(xone['sales'])
print('Корреляция между продажами и оценкой пользователей : ',c)
# Out:
# Корреляция между продажами и оценкой пользователей :  -0.06892505328279414

# %%
c1 = xone['critic_score'].corr(xone['sales'])
print('Корреляция между продажами и оценкой критиков : ',c1)
# Out:
# Корреляция между продажами и оценкой критиков :  0.2748391874944539

# %% [markdown]
# Построим диаграмму рассеяния

# %%
plt.figure(figsize=(10,10))
plt.title('Диаграмма рассеяния по оценкам пользователей')
sns.scatterplot(data=xone, x='user_score', y='sales')

# %%
plt.figure(figsize=(10,10))
plt.title('Диаграмма рассеяния по оценкам критиков')
sns.scatterplot(data=will, x='critic_score', y='sales')

# %% [markdown]
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Построим диаграмму рассеивания для остальных 4-х популярных платформ за актуальный период.

# %% [markdown]
# У play station 4

# %%
PS4 = games[games['platform']=='PS4']
p_4 = PS4['user_score'].corr(PS4['sales'])
print('Корреляция между продажами и оценкой пользователей PS4: ',p_4) 

p_s_4 = PS4['critic_score'].corr(PS4['sales'])
print('Корреляция между продажами и оценкой критиков PS4: ',p_s_4)

plt.figure(figsize=(12,6))
sns.scatterplot(x='user_score', y='sales', data=PS4)
plt.title('Диаграмма рассеивания между общими продажами и пользовательской оценкой у PS4')

plt.figure(figsize=(12,6))
sns.scatterplot(x='critic_score', y='sales', data=PS4)
plt.title('Диаграмма рассеивания между общими продажами и оценкой критиков у PS4')
# Out:
# Корреляция между продажами и оценкой пользователей PS4:  -0.031957110204556424
# Корреляция между продажами и оценкой критиков PS4:  0.22754960627752652
# Text(0.5, 1.0, 'Диаграмма рассеивания между общими продажами и оценкой критиков у PS4')

# %% [markdown]
# У РС

# %%
PC = games[games['platform']=='PC']

x3 = PC['user_score'].corr(PC['sales'])
print('Корреляция между продажами и оценкой пользователей : ',x3) 

x3_1 = PC['critic_score'].corr(PC['sales'])
print('Корреляция между продажами и оценкой критиков : ',x3_1)

plt.figure(figsize=(12,6))
sns.scatterplot(x='user_score', y='sales', data=PC)
plt.title('Диаграмма рассеивания между общими продажами и пользовательской оценкой у PC')

plt.figure(figsize=(12,6))
sns.scatterplot(x='critic_score', y='sales', data=PC)
plt.title('Диаграмма рассеивания между общими продажами и оценкой критиков у PC')
# Out:
# Корреляция между продажами и оценкой пользователей :  0.010475684621486417
# Корреляция между продажами и оценкой критиков :  0.07973661320683437
# Text(0.5, 1.0, 'Диаграмма рассеивания между общими продажами и оценкой критиков у PC')

# %% [markdown]
# У WiiU

# %%
WiiU = games[games['platform']=='WiiU']

p3 = WiiU['user_score'].corr(WiiU['sales'])
print('Корреляция между продажами и оценкой пользователей : ',p3) 

p3_1 = WiiU['critic_score'].corr(WiiU['sales'])
print('Корреляция между продажами и оценкой критиков : ',p3_1)


plt.figure(figsize=(10,10))
sns.scatterplot(x='user_score', y='sales', data=WiiU)
plt.title('Диаграмма рассеивания между общими продажами и пользовательской оценкой у WiiU')

plt.figure(figsize=(12,6))
sns.scatterplot(x='critic_score', y='sales', data=WiiU)
plt.title('Диаграмма рассеивания между общими продажами и оценкой критиков у WiiU')
# Out:
# Корреляция между продажами и оценкой пользователей :  0.4002190202148617
# Корреляция между продажами и оценкой критиков :  0.29812398749349167
# Text(0.5, 1.0, 'Диаграмма рассеивания между общими продажами и оценкой критиков у WiiU')

# %% [markdown]
# У 3DS

# %%
DS = games[games['platform']=='3DS']

d = DS['user_score'].corr(DS['sales'])
print('Корреляция между продажами и оценкой пользователей : ',d) 

d_1 = DS['critic_score'].corr(DS['sales'])
print('Корреляция между продажами и оценкой критиков : ',d_1)

plt.figure(figsize=(12,6))
sns.scatterplot(x='user_score', y='sales', data=DS)
plt.title('Диаграмма рассеивания между общими продажами и пользовательской оценкой у DS')

plt.figure(figsize=(12,6))
sns.scatterplot(x='critic_score', y='sales', data=DS)
plt.title('Диаграмма рассеивания между общими продажами и оценкой критиков у DS')
# Out:
# Корреляция между продажами и оценкой пользователей :  0.22480798039571082
# Корреляция между продажами и оценкой критиков :  0.1672385348032063
# Text(0.5, 1.0, 'Диаграмма рассеивания между общими продажами и оценкой критиков у DS')

# %% [markdown]
# По полученным данным можно сделать несколько выводов:
#  Оценка критиков оказывает больше влияния на продажу игры, чем оценка пользователей
#  У всех платформ есть корреляция между оценкой пользователей и общими продажами, а также между оценкой критиков и общими продажами.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Результат получен. Подумай, чем он вызван. Здорово, что рассмотрены несколько платформ.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Посмотри на результаты без значений 0, которыми ты обработала пропуски.
#
# </div>

# %% [markdown]
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
genre_distribution = games.pivot_table(index='genre', values='sales', aggfunc='sum').sort_values(by='sales', ascending=False)
genre_distribution = genre_distribution.reset_index().rename_axis(None, axis=1)
genre_distribution
# Out:
#            genre    sales
# 0         Action  1744.17
# 1         Sports  1331.27
# 2        Shooter  1052.45
# 3   Role-Playing   934.56
# 4       Platform   827.77
# 5           Misc   802.51
# 6         Racing   728.67
# 7       Fighting   447.53
# 8     Simulation   389.97
# 9         Puzzle   242.57
# 10     Adventure   237.59
# 11      Strategy   174.23
# 12           nan     2.42

# %%
plt.figure(figsize=(12, 5))

plt.title('Распределение игр по жанрам')
sns.barplot(data=genre_distribution, x='genre', y='sales')

plt.xlabel('Жанры компьютерных игр')
plt.ylabel('Продажи')
# Out:
# Text(0, 0.5, 'Продажи')

# %% [markdown]
# Самыми популярными жанрами являются экшн, спортивные и шутеры, а самыми непопулярными приключения и стратегии

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Анализ популярности жанров проведен. Однако не стоит забывать, что производство игр в жанрах Action или Shooter обходится сильно дороже, чем производство Puzzle-игр.
#
# </div>

# %% [markdown]
# ## Составим портрет пользователя каждого региона

# %% [markdown]
# Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# #### Портрет пользователя North America

# %% [markdown]
# Самые популярные платформы (топ-5) в Северной Америке

# %%
top_pl_na = games.pivot_table(values = 'na_sales', index ='platform',aggfunc='sum').sort_values(by='na_sales', ascending=False)
top_pl_na = top_pl_na.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по платформам в Северной Америке')
sns.barplot(data=top_pl_na, x='platform', y='na_sales')
plt.xlabel('Топ-5 платформ')
plt.ylabel('Продажи в Северной Америке')
print(top_pl_na)
# Out:
#   platform  na_sales
# 0     X360    602.47
# 1      PS2    583.84
# 2      Wii    496.90
# 3      PS3    393.49
# 4       DS    382.40

# %% [markdown]
# Самые популярные жанры (топ-5) в Северной Америке

# %%
top_genre_na = games.pivot_table(values = 'na_sales', index ='genre',aggfunc='sum').sort_values(by='na_sales', ascending=False)
top_genre_na = top_genre_na.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по жанрам в Северной Америке')
sns.barplot(data=top_genre_na, x='genre', y='na_sales')
plt.xlabel('Топ-5 жанров')
plt.ylabel('Продажи в Северной Америке')
print(top_genre_na)
# Out:
#       genre  na_sales
# 0    Action    879.01
# 1    Sports    684.43
# 2   Shooter    592.24
# 3  Platform    445.50
# 4      Misc    407.27

# %% [markdown]
# Рейтинг по играм в Северной Америке

# %%
top_rating_na = games.pivot_table(values = 'na_sales', index ='rating',aggfunc='sum').sort_values(by='na_sales', ascending=False)
top_rating_na = top_rating_na.reset_index().rename_axis(None, axis=1)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по рейтингу в Северной Америке')
sns.barplot(data=top_rating_na, x='rating', y='na_sales')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи в Северной Америке')
print(top_rating_na)
# Out:
#   rating  na_sales
# 0      E   1292.99
# 1    nan   1242.46
# 2      T    759.75
# 3      M    748.48
# 4   E10+    353.32
# 5    K-A      2.56
# 6     EC      1.53
# 7     AO      1.26
# 8     RP      0.00

# %% [markdown]
# Самые популярные игровые платформы в Северной Америке это: XBOX, PS2, WII, PS3, DS. Топ 5 жанров в северной америке : action, sports, shooter, platform, misc.

# %% [markdown]
# #### Портрет пользователя в Европе

# %% [markdown]
# Самые популярные жанры (топ-5) в Европе

# %%
top_pl_e = games.pivot_table(values = 'eu_sales', index ='platform',aggfunc='sum').sort_values(by='eu_sales', ascending=False)
top_pl_e = top_pl_e.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по платформам в Европе')
sns.barplot(data=top_pl_e, x='platform', y='eu_sales', palette='Set3')
plt.xlabel('Топ-5 платформ')
plt.ylabel('Продажи в Европе')
print(top_pl_e)
# Out:
#   platform  eu_sales
# 0      PS2    339.29
# 1      PS3    330.29
# 2     X360    270.76
# 3      Wii    262.21
# 4       PS    213.61

# %% [markdown]
# Распределение игр по жанрам в Европе

# %%
top_genre_eu = games.pivot_table(values = 'eu_sales', index ='genre',aggfunc='sum').sort_values(by='eu_sales', ascending=False)
top_genre_eu = top_genre_eu.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по жанрам в Европе')
sns.barplot(data=top_genre_eu, x='genre', y='eu_sales', palette='Set3')
plt.xlabel('Топ-5 жанров')
plt.ylabel('Продажи в Европе')
print(top_genre_eu)
# Out:
#      genre  eu_sales
# 0   Action    519.13
# 1   Sports    376.79
# 2  Shooter    317.34
# 3   Racing    236.51
# 4     Misc    212.74

# %% [markdown]
# Распределение игр по рейтингу в Европе

# %%
top_rating_eu = games.pivot_table(values = 'eu_sales', index ='rating',aggfunc='sum').sort_values(by='eu_sales', ascending=False)
top_rating_eu = top_rating_eu.reset_index().rename_axis(None, axis=1)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по рейтингу в Европе')
sns.barplot(data=top_rating_eu, x='rating', y='eu_sales', palette='Set3')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи в Европе')
print(top_rating_eu)
# Out:
#   rating  eu_sales
# 0      E    710.25
# 1    nan    613.83
# 2      M    483.97
# 3      T    427.03
# 4   E10+    188.52
# 5     AO      0.61
# 6    K-A      0.27
# 7     EC      0.11
# 8     RP      0.08

# %% [markdown]
# Самые популярные игровые платформы в Европе это: PS2, PS3, XBOX, WII, PS. Топ 5 жанров в Европе : action, sports, shooter, racing, misc.

# %% [markdown]
# #### Портрет пользователя Японии

# %% [markdown]
# Самые популярные платформы (топ-5) в Японии

# %%
top_pl_j = games.pivot_table(values = 'jp_sales', index ='platform',aggfunc='sum').sort_values(by='jp_sales', ascending=False)
top_pl_j = top_pl_j.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по платформам в  Японии')
sns.barplot(data=top_pl_j, x='platform', y='jp_sales', palette='PuOr')
plt.xlabel('Топ-5 платформ')
plt.ylabel('Продажи в  Японии')
print(top_pl_j)
# Out:
#   platform  jp_sales
# 0       DS    175.57
# 1       PS    139.82
# 2      PS2    139.20
# 3     SNES    116.55
# 4      3DS    100.67

# %% [markdown]
# Самые популярные жанры (топ-5) в Японии

# %%
top_genre_jp = games.pivot_table(values = 'jp_sales', index ='genre',aggfunc='sum').sort_values(by='jp_sales', ascending=False)
top_genre_jp = top_genre_jp.reset_index().rename_axis(None, axis=1).head(5)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по жанрам в  Японии')
sns.barplot(data=top_genre_jp, x='genre', y='jp_sales', palette='PuOr')
plt.xlabel('Топ-5 жанров')
plt.ylabel('Продажи в  Японии')
print(top_genre_jp)
# Out:
#           genre  jp_sales
# 0  Role-Playing    355.41
# 1        Action    161.43
# 2        Sports    135.54
# 3      Platform    130.83
# 4          Misc    108.11

# %% [markdown]
# Распределение игр по рейтингу в Японии

# %%
top_rating_jp = games.pivot_table(values = 'jp_sales', index ='rating',aggfunc='sum').sort_values(by='jp_sales', ascending=False)
top_rating_jp = top_rating_jp.reset_index().rename_axis(None, axis=1)
plt.figure(figsize=(10, 10))
plt.title('Распределение игр по рейтингу в  Японии')
sns.barplot(data=top_rating_jp, x='rating', y='jp_sales', palette='PuOr')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи в  Японии')
print(top_rating_jp)
# Out:
#   rating  jp_sales
# 0    nan    841.96
# 1      E    198.11
# 2      T    151.40
# 3      M     64.24
# 4   E10+     40.20
# 5    K-A      1.46
# 6     AO      0.00
# 7     EC      0.00
# 8     RP      0.00

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Круто, ты заметила важную особенность данных - большая часть игр японского региона не имеет рейтинга. Как думаешь, почему мы получаем такой результат?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Портрет типичного пользователя каждого из регионов получен. Приведены все необходимые графики. Здорово, что отмечены индивидуальные особенности каждого региона.
#
# </div>

# %% [markdown]
# ## Проведем исследование статистических показателей

# %% [markdown]
# Как изменяется пользовательский рейтинг и рейтинг критиков в различных жанрах? Посчитайте среднее количество, дисперсию и стандартное отклонение. Постройте гистограммы. Опишите распределения

# %% [markdown]
# Создадим список, состоящий из жанров игр

# %%
genre_list = games['genre'].unique()
genre_list = genre_list[:-1]

# %% [markdown]
# Посчитаем среднее количество, дисперсия и стандартное отклонение, а также построим гистаграмму

# %%
for g in genre_list:
    print(g)
    fig, axes = plt.subplots()
    user_s = games[(games['genre'] == g)  & (games['user_score'] > 0)]['user_score'] * 10
    plt.hist([games[(games['genre'] == g)  & (games['user_score'] > 0)]['user_score']* 10, games[(games['genre'] == g) & (games['critic_score'] > 0)]['critic_score']], color = ['purple', 'thistle'],  label = ['user_score', 'critic_score'])
    plt.legend()
    plt.title(g)
    plt.xlabel('Рейтинг')
    plt.ylabel('Количество игр')
    print('Среднее количество, дисперсия и стандартное отклонение по оценкам пользователей')
    print('Среднее количество', user_s.mean())
    print('Дисперсия', np.var(games[(games['genre']==g) &(games['user_score'] > 0)]['user_score']))
    print('Стандартное отклонение', np.std(games[(games['genre']==g) & (games['user_score'] > 0)]['user_score']))
    print(" ")
    print('Среднее количество, дисперсия и стандартное отклонение по оценкам критиков')
    print('Среднее количество', games[(games['genre']==g) & (games['critic_score'] > 0)]['critic_score'].mean())
    print('Дисперсия', np.var(games[(games['genre']==g) & (games['critic_score'] > 0)]['critic_score']))
    print('Стандартное отклонение', np.std(games[(games['genre']==g)& (games['critic_score'] > 0)]['critic_score']))
    print(" ")
    print(" ")
# Out:
# Sports
# Среднее количество, дисперсия и стандартное отклонение по оценкам пользователей
# Среднее количество 69.61196736174071
# Дисперсия 2.594160671177017
# Стандартное отклонение 1.6106398328543279
#
# Среднее количество, дисперсия и стандартное отклонение по оценкам критиков
# Среднее количество 71.96817420435511
# Дисперсия 192.44957338338818
# Стандартное отклонение 13.872619557365082
#
#
# Platform
# Среднее количество, дисперсия и стандартное отклонение по оценкам пользователей
# Среднее количество 73.01401869158879
# Дисперсия 2.2856989693423007
# Стандартное отклонение 1.5118528266145157
#
# Среднее количество, дисперсия и стандартное отклонение по оценкам критиков
# Среднее количество 68.05835010060362
# Дисперсия 174.25212846495472
# Стандартное отклонение 13.200459403556936
#
#
# Racing
# Среднее количество, дисперсия и стандартное отклонение по оценкам пользователей
# Среднее количество 70.3619344773791
# Дисперсия 2.38795680501167
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# По каждому графику работы проверь подписи осей. Без этого сложно понять, что именно мы анализируем. Посмотри на распределения без обработки пропусков.
#
# </div>

# %% [markdown]
# Oбщее распределение оценок пользователей и критиков

# %%
plt.hist([games[games['user_score'] > 0]['user_score']*10, games[games['critic_score'] > 0]['critic_score']], color = ['purple', 'thistle'],  label = ['user_score', 'critic_score'])
plt.xlabel('Рейтинг')
plt.ylabel('Количество игр')
plt.legend()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Подписи осей теперь появились. Отфильтруй нереальные значения из анализа и посмотри на получаемые результаты.
# </div>

# %% [markdown]
# ## Проверка гипотезы

# %% [markdown]
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.

# %% [markdown]
# Возьмем за нулевую гипотезу, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Тогда альтернативной гипотезой будет то, что рейтинги данных платформ разные.

# %% [markdown]
# Н0 : Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# Н1 : Средние пользовательские рейтинги платформ Xbox One и PC разные.

# %% [markdown]
# Запишем в отдельную переменную пользовательский рейтинг для каждой из платформ

# %%
xbox_score = games[(games['platform']=='XOne') & (games['user_score'] > 0)]['user_score'].dropna()
pc_score = games[(games['platform']=='PC') & (games['user_score'] > 0)]['user_score'].dropna()

# %%
xbox_score
# Out:
# 165      7.9
# 179      5.4
# 242      6.4
# 270      6.2
# 373      4.1
#         ...
# 16544    6.8
# 16597    6.0
# 16630    8.2
# 16643    6.6
# 16660    6.7
# Name: user_score, Length: 182, dtype: float64

# %%
xbox_score.mean()
pc_score.mean()
# Out:
# 7.062467532467533

# %%
alpha = 0.05
results = st.ttest_ind(xbox_score, pc_score, equal_var=False)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.935072360183565e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# Отвергаем нулевую гипотезу, значит, у нас практически нет вероятности получить одинакове средние рейнтинги по двум платформам.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Гипотезы сформулированы и проверены верно. Посмотри на результаты при анализе актуальных данных.
#
# </div>

# %% [markdown]
# Возьмем за нулевую гипотезу, что средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») одинаковые. Тогда альтернативной гипотезой будет то, что рейтинги данных жанров разные.
#
# Н0 : Средние пользовательские рейтинги жанров Action и Sports  одинаковые.
# Н1 : Средние пользовательские рейтинги жанров Action и Sports разные.

# %%
action_score = games[(games['genre']=='Action') & (games['user_score'] > 0)]['user_score']
sports_score= games[(games['genre']=='Sports')& (games['user_score'] > 0)]['user_score']

# %%
alpha = 0.05
results = st.ttest_ind(action_score.dropna(), sports_score.dropna(), equal_var=False)
print('p-значение:', results.pvalue)
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.11483818791498286
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Значение p-value равно 0.1148. Cледовательно, не получилось отвергнуть нулевую гипотезу. Для того чтобы средние пользовательские рейтинги жанров Action и Sports были разные, нам нужно раздвинуть доверительный интервал на 11,4 %.

# %% [markdown]
# Вывод по проверке гипотез функцией ttest_ind:
# - Гипотеза: "Средние пользовательские рейтинги платформ Xbox one и PC одинаковые".Отвергаем нулевую гипотезу.
# - Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports разные".Не получилось отвергнуть нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Проверка второй гипотезы также выполнена без нареканий.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# При проверке гипотез в выборках также содержатся значения 0, которыми ты отметила пропуски. Анализировать их не стоит, т.к. это нереальные данные.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Перед анализом данных мы подготовили  данные, привели к правильным данным столбцы, привели к нижнему регистру названия колонок. Привели к правильным типам данных необходимые столбцы и заполнили пропуски.

# %% [markdown]
# Самые популярные платформами с 1980 по 2016 год: PS2, X360, PS3, WII, DS, PS. По графику определили, что от момента появления платформ до спада продаж в среднем проходит 10 лет. Самый пик продаж наступает примерно через 5 лет после выпуска платформы.
# У платформ, лидирующих по продажам, наблюдается взаимосвязь между продажами и оценками критиков. Пользовательские оценки не влияют. Следовательно, мнение критиков важнее мнения других пользователей. Самый популярный жанр за последние 10 лет: 'Action'.

# %% [markdown]
# Портреты пользователей каждого региона:
#
# - Самые популярные игровые платформы в Северной Америке это: XBOX, PS2, WII, PS3, DS. Топ 5 жанров в северной америке : action, sports, shooter, platform, misc. По рейтингам видно, что больше всего продаж у игр с рейтингом "для всех", на втором месте игры с рейтингом "от 13 и выше" и затем игры с рейтингом "от 17 и выше".
#
# - Самые популярные игровые платформы в Европе это: PS2, PS3, XBOX, WII, PS. Топ 5 жанров в Европе : action, sports, shooter, racing, misc. По рейтингам видно, что больше всего продаж у игр с рейтингом "для всех", на втором месте игры с рейтингом "от 17 и выше" и на затем игры с рейтингом "от 13 и выше".
#
# - Самые популярные игровые платформы в Японии это: DS, PS, PS2, SNES, 3DS. Топ 5 жанров в Японии : Role-Playing, action, sports, platform, misc. По рейтингам видно, что больше всего продаж у игр с рейтингом "для всех", на втором месте игры с рейтингом "от 13 и выше" и затем игры с рейтингом "от 17 и выше".

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Выводы описаны грамотно. Приведены ответы на главные вопросы проекта. В выводах можно приводить полученные ранее значения, правильно. Здорово, что по каждому пункту работы приведен вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Если тебе нравится тема визуализации, то можешь изучить другие методы библиотеки seaborn. Она позволяет строить довольно презентабельные графики. Здорово, что ты вообще используешь данную библиотеку.
#
# Ты выполнила все пункты работы, молодец! Критических замечаний немного. Однако с ними важно поработать и их исправить.  Также есть достаточное число желтых комментариев, которые стоит исправить. Думаю, ты справишься с этим быстро. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера 2</b></font>
#
# Основная часть помарок исправлена. Осталось совсем немного. Не следует заполнять пропуски нереальными данными и включать их в анализ. Это сильно сказывается на результате. Как испарвишь это, присылай работу снова. Буду ждать :)
#
# </div>
